# %% [markdown]
# # **NAME** : Baidoo Kobina Manso

# %% [markdown]
# # **ID** : 10955922

# %% [markdown]
# # **DEPT.** : Computer Engineering

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# # Removing Null Values
# ### Nulls values cannot be filled in because we do not have accurate information or records to input and can affect the results so they have to be removed for accurate data analysis. The __.isnull__ function is used to drop null values.

# %%
df.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %%
df=df.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity','citric acid':'citric_acid','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %%
df
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed_acidity         1591 non-null   float64
#  2   volatile_acidity      1591 non-null   float64
#  3   citric_acid           1591 non-null   float64
#  4   residual_sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free_sulfur_dioxide   1591 non-null   float64
#  7   total_sulfur_dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %%
df.isnull()
# Out:
#          ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# 5     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 1596  False          False             False        False           False
# 1597  False          False             False        False           False
# 1598  False          False             False        False           False
# 1599  False          False             False        False           False
# 1600  False          False             False        False           False
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density     pH  \
# ...

# %%
dfFill=df.mean()

# %%
dfFill
# Out:
# ID                      801.060968
# fixed_acidity             8.320616
# volatile_acidity          0.527681
# citric_acid               0.271477
# residual_sugar            2.540761
# chlorides                 0.087500
# free_sulfur_dioxide      15.861722
# total_sulfur_dioxide     46.498429
# density                   0.996747
# pH                        3.311358
# sulphates                 0.658611
# alcohol                  10.426053
# quality                   5.637964
# dtype: float64

# %%
df=df.fillna(dfFill).drop_duplicates()
# Fills the missing values in the df with the values from dfFill, which contains the mean of each column in df and removes any duplicate rows from df.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1591 non-null   int64
#  1   fixed_acidity         1591 non-null   float64
#  2   volatile_acidity      1591 non-null   float64
#  3   citric_acid           1591 non-null   float64
#  4   residual_sugar        1591 non-null   float64
#  5   chlorides             1591 non-null   float64
#  6   free_sulfur_dioxide   1591 non-null   float64
#  7   total_sulfur_dioxide  1591 non-null   float64
#  8   density               1591 non-null   float64
#  9   pH                    1591 non-null   float64
#  10  sulphates             1591 non-null   float64
#  11  alcohol               1591 non-null   float64
#  12  quality               1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %%
df['citric_acid'].hist(bins=10, color='red')
plt.show()

# %%
df['fixed_acidity'].hist(bins=10)
plt.show()

# %%
df['volatile_acidity'].hist(bins=10)
plt.show()

# %%
df['residual_sugar'].hist(bins=10)
plt.show()

# %%
df['free_sulfur_dioxide'].hist(bins=10)
plt.show()

# %%
df['chlorides'].hist(bins=10)
plt.show()

# %%
df['total_sulfur_dioxide'].hist(bins=10)
plt.show()

# %%
df['density'].hist(bins=10)
plt.show()

# %%
df['sulphates'].hist(bins=10)
plt.show()

# %%
df['alcohol'].hist(bins=10)
plt.show()

# %%
df['pH'].hist(bins=10)
plt.show()

# %%
df['quality'].hist(bins=10)
plt.show()

# %%
plt.scatter(df['chlorides'],df['free_sulfur_dioxide'], color='red')
plt.show()

# %%
plt.scatter(df['fixed_acidity'],df['volatile_acidity'])
plt.show()

# %%
plt.scatter(df['sulphates'],df['alcohol'])
plt.show()

# %%
plt.scatter(df['pH'],df['alcohol'])
plt.show()

# %%
df['fixed_acidity'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='fixed_acidity'>

# %%
df['sulphates'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='sulphates'>

# %%
df['alcohol'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <AxesSubplot:ylabel='alcohol'>

# %%
df.corr()
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.268371         -0.006833    -0.156712
# fixed_acidity        -0.268371       1.000000         -0.256737     0.672306
# volatile_acidity     -0.006833      -0.256737          1.000000    -0.551511
# citric_acid          -0.156712       0.672306         -0.551511     1.000000
# residual_sugar       -0.031780       0.114839          0.001336     0.143731
# chlorides            -0.119930       0.093857          0.061202     0.204294
# free_sulfur_dioxide   0.085616      -0.150261         -0.014598    -0.057619
# total_sulfur_dioxide -0.115795      -0.110992          0.074132     0.038593
# density              -0.368878       0.666876          0.022504     0.364181
# pH                    0.133390      -0.683788          0.234251    -0.543230
# sulphates            -0.127397       0.184937         -0.261872     0.313530
# ...
